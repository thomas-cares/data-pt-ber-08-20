# %%
import json
import requests
import pandas as pd

# %% [markdown]
# ### Challenge 1: Forks

# %% [markdown]
# #### Obtain the full list of forks created from the main lab repo via the Github API.

# %%
# Create variables which contain your user name and your token
git_user='thomas-cares'
git_token='2b28d8bd17402c54cea43c68ab5c87b399dcfe54'
#curl -u johndoe:d10ev1shpm10x5qox9ckw1k9b792p9rq0ogplpn5cyo55 https://api.github.com/user

# %%
# Retrieve a json file with information on all of the forks. You will need an "auth" argument here for authentication!
url='https://api.github.com/repos/ironhack-datalabs/data-pt-ber-08-20/forks'
results=requests.get(url, auth=(git_user, git_token)).json()
df_repos=pd.json_normalize(results)
df_repos
#results
# Out:
#            id                           node_id                      name  \
# 0   300694721  MDEwOlJlcG9zaXRvcnkzMDA2OTQ3MjE=         data-pt-ber-08-20
# 1   298860128  MDEwOlJlcG9zaXRvcnkyOTg4NjAxMjg=         data-pt-ber-08-20
# 2   294426750  MDEwOlJlcG9zaXRvcnkyOTQ0MjY3NTA=         data-pt-ber-08-20
# 3   292589379  MDEwOlJlcG9zaXRvcnkyOTI1ODkzNzk=         data-pt-ber-08-20
# 4   292087056  MDEwOlJlcG9zaXRvcnkyOTIwODcwNTY=         data-pt-ber-08-20
# 5   291494254  MDEwOlJlcG9zaXRvcnkyOTE0OTQyNTQ=         data-pt-ber-08-20
# 6   290842466  MDEwOlJlcG9zaXRvcnkyOTA4NDI0NjY=         data-pt-ber-08-20
# 7   290840493  MDEwOlJlcG9zaXRvcnkyOTA4NDA0OTM=         data-pt-ber-08-20
# 8   290833247  MDEwOlJlcG9zaXRvcnkyOTA4MzMyNDc=         data-pt-ber-08-20
# 9   290832333  MDEwOlJlcG9zaXRvcnkyOTA4MzIzMzM=  data-pt-ber-08-20-shinan
# 10  290832254  MDEwOlJlcG9zaXRvcnkyOTA4MzIyNTQ=         data-pt-ber-08-20
# 11  290831811  MDEwOlJlcG9zaXRvcnkyOTA4MzE4MTE=         data-pt-ber-08-20
# ...

# %%
# Normalize semi-structured JSON data into a dataframe.

# %% [markdown]
# #### Extract a list of all the usernames of people who have forked this repo.

# %%
df_repos['owner'][0].keys()
# Out:
# dict_keys(['login', 'id', 'node_id', 'avatar_url', 'gravatar_id', 'url', 'html_url', 'followers_url', 'following_url', 'gists_url', 'starred_url', 'subscriptions_url', 'organizations_url', 'repos_url', 'events_url', 'received_events_url', 'type', 'site_admin'])

# %%
# Your code:
usernames=[df_repos['owner'][i]['login'] for i in range(len(df))]
usernames
# Out:
# ['Abdou-Man-24',
#  'Seetank',
#  'joao-dias-25',
#  'filipamiralopes',
#  'sholaayodele',
#  'danielquer',
#  'BehroozGharleghi',
#  'Ayomi-tech',
#  'Najla-Sh',
#  'Shinan-tech',
#  'ksaslow',
#  'cabulut',
#  'davidegonzale',
#  'vikkieessien',
#  'Benedkt93',
#  'thomas-cares',
#  'christinahans',
#  'pepenunez']

# %% [markdown]
# ### Challenge 2: Count Commits

# %% [markdown]
# Obtain a dataframe which contains all of the commits made. From this dataframe, extract a list of all the commit messages. Also, count how many commits have been made.

# %%
# Your code:
url='https://api.github.com/repos/ironhack-datalabs/data-pt-ber-08-20/commits'
results=requests.get(url, auth=(git_user, git_token)).json()
df_commit = pd.json_normalize(results)
#df_commits=pd.DataFrame(results)
df_commit
# Out:
#                                          sha  \
# 0   4dbb1213b78e23b845251e12ae2389d2f6bd653d
# 1   212da9f2090430347f0614d9b094ddb3a4f98ff4
# 2   d79fe770a8da68b3bd579906a8b5a6cc38988fa3
# 3   31c5316c3e04e790fa3e393ebe9f67f55a343f04
# 4   dbda871347f31d996d382bf5e64606daae7b1168
# 5   7efdfc87a550d73bf4897d632a5a9f4e5feccc87
# 6   78ce571ff02ab2c384a521a5b095978ba12255bb
# 7   ebefe5930ec44dc6c85a7da6a70bfd157388f076
# 8   d492b5b0938fef50e4dbfc5599c2c44b79152d5f
# 9   8b693b361703ceb4cd48fcb5f27a5742579e0303
# 10  b90d3032ca387db8a089bec50f39a07c402716d7
# 11  1992694b107050728c9afc22c45208011856fa91
# 12  e842980cab6c7c2ea7ee5d2bda96fe2908b5e251
# 13  6d3ddcee6ad6cd347e2d624fce28e1f464a41603
# 14  7fe797f3eb833e54b6eadd678afb780af297a2a8
# 15  d6b0c94505267a0d7240e562a9b347c60406db87
# 16  b312b6a56f2b55f06ec85836512fd10593ed6345
# 17  07d0a320c8785b7bdeb5c1a2fc41cdc2bfc780aa
# 18  2de08c3fd77acded7b365585faf5f2dab3283a93
# 19  9f698caecdf581eb165c790ee5912c909a6ee0f8
# ...

# %%
df_commits['commit.message']
# Out:
# 0                           solutions lab-coingecko-api
# 1                                      adding api-class
# 2                          solutions lab-advanced-regex
# 3     Merge branch 'master' of https://github.com/ir...
# 4                                             scavenger
# 5     Merge branch 'master' of https://github.com/ir...
# 6                                  class advanced regex
# 7                                               project
# 8                                         coingecko api
# 9                            solutions lab-web-scraping
# 10                            adding web-scraping-class
# 11    Merge branch 'master' of https://github.com/ir...
# 12                                     web scraping lab
# 13                        solutions basics_plotting lab
# 14                         adding plotting-basics-class
# 15                                   basic plotting lab
# 16                                        rem solutions
# ...

# %% [markdown]
# #### Bonus Challenge: Obtain all of the commits that have been made in the past week (specify the date using a 'since' argument).

# %%
# Your code:

# %%
###creat hidden files with credantials
import json

git_user='thomas-cares'
git_token='2b28d8bd17402c54cea43c68ab5c87b399dcfe54'

cred={}
cred['user_name'] = 'git_user'
cred['token'] = '2b28d8bd17402c54cea43c68ab5c87b399dcfe54'

with open ('github_credentials.json', 'w') as outfile:
    outfile.write
