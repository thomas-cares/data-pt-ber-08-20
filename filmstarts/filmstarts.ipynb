# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
from pprint import pprint
from lxml import html
from lxml.html import fromstring
import urllib.request
from urllib.request import urlopen
import random
import re
import time
import subprocess

#import scrapy

# %%
def make_soup(url):
    html=requests.get(url).content
    return BeautifulSoup(html,'html.parser')

# %%
#AKTUELLE WOCHE WEEK 0
week_0='https://www.kino-zeit.de/filme/filmstarts/aktuell'
soup= make_soup(week_0)

# %%
#Filmtitel der jeweils aktuellen Seite
films_0_titel=[i.text for i in soup.find_all(['h3','a'],{'class': 'filmlink'})]
df_0=pd.DataFrame(films_0_titel)
df_0.columns = ['Filmtitel']
df_0
# Out:
#                                             Filmtitel
# 0   Contemporary Past - Die Gegenwart der Vergange...
# 1   Die Misswahl - Der Beginn einer Revolution (2020)
# 2                                Drachenreiter (2020)
# 3                              Enfant Terrible (2020)
# 4                                  Good Kisser (2019)
# 5              Gott, du kannst ein Arsch sein! (2020)
# 6                     Hurtigruten und Norwegen (2020)
# 7                   Jim Knopf und die wilde 13 (2020)
# 8                Niemals Selten Manchmal Immer (2020)
# 9                                 On the Rocks (2020)
# 10                                   Streltsov (2020)
# 11                  The Trial of the Chicago 7 (2020)

# %%
#Link zur Filmseite
films_pglnk_0=[f'https://www.kino-zeit.de{i["href"]}' for i in soup.find_all(["h3","a"],{"class": "filmlink"})]
films_pglnk_0
df_0['page_link']=films_pglnk_0

# %%
#Starttermin
films_start_0=[i.text for i in soup.find_all('div',{'class':'col-md-2 infospalte-1'})]
films_start_0 = re.findall(r'\d\d.\d\d.\d\d\d\d', str(films_start_0))
df_0['Starttermin']=films_start_0
df_0
# Out:
#                                             Filmtitel  \
# 0   Contemporary Past - Die Gegenwart der Vergange...
# 1   Die Misswahl - Der Beginn einer Revolution (2020)
# 2                                Drachenreiter (2020)
# 3                              Enfant Terrible (2020)
# 4                                  Good Kisser (2019)
# 5              Gott, du kannst ein Arsch sein! (2020)
# 6                     Hurtigruten und Norwegen (2020)
# 7                   Jim Knopf und die wilde 13 (2020)
# 8                Niemals Selten Manchmal Immer (2020)
# 9                                 On the Rocks (2020)
# 10                                   Streltsov (2020)
# 11                  The Trial of the Chicago 7 (2020)
#
#                               page_link Starttermin
# 0   https://www.kino-zeit.de/node/50404  01.10.2020
# 1   https://www.kino-zeit.de/node/48346  01.10.2020
# 2   https://www.kino-zeit.de/node/49005  01.10.2020
# 3   https://www.kino-zeit.de/node/48025  01.10.2020
# 4   https://www.kino-zeit.de/node/50833  01.10.2020
# 5   https://www.kino-zeit.de/node/50476  01.10.2020
# 6   https://www.kino-zeit.de/node/50852  01.10.2020
# 7   https://www.kino-zeit.de/node/48472  01.10.2020
# 8   https://www.kino-zeit.de/node/48347  01.10.2020
# 9   https://www.kino-zeit.de/node/50572  02.10.2020
# 10  https://www.kino-zeit.de/node/50783  04.10.2020
# 11  https://www.kino-zeit.de/node/50731  01.10.2020

# %%
###WEEK 0###
regie_list=[]
darsteller_list=[]
list_img_url=[]
list_verleih=[]
list_prodland=[]

for i in df_0['page_link']:   
    sub_page=make_soup(i)
    regie=[i.text.replace('\nRegie','').replace('\n\n','').split(',') for i in sub_page.find_all('div',{'class':'field field--name-field-regie field--type-entity-reference field--label-above'})]
    regie_list.append(regie[0])
    darsteller=[i.text.replace('\nDarsteller','').split('\n') for i in sub_page.find_all('div',{'class':'field field--name-field-hauptdarsteller field--type-entity-reference field--label-above'})]
    darsteller_list.append(darsteller)
    img_url=[i['data-big'] for i in sub_page.find_all('img',{'id':'headerbildbig'})]
    list_img_url.append(img_url)
    verleih=[i.text.replace('\nFilmverleih','').replace('\n\n','') for i in sub_page.find_all(['div','a'],{'class':'field field--name-field-distribution-film field--type-entity-reference field--label-above'})]
    list_verleih.append(verleih)
    prodland=[i.text.replace('\nProduktionsland','').replace('\n\n','') for i in sub_page.find_all(['div','a'],{'class':'field field--name-field-produktionsland field--type-entity-reference field--label-above'})]
    list_prodland.append(prodland)
    
df_0['Regie']=regie_list
df_0['Darsteller']=darsteller_list
df_0['Foto']=list_img_url
df_0['Verleih']=list_verleih
df_0['Produktionsland']=list_prodland
#df_0

# %%
####WEEK_1#####

week_1=''.join([f'https://www.kino-zeit.de/filme/filmstarts/{i["href"]}' for i in soup.find_all("a",{"class": "next btn btn-primary"})])
soup= make_soup(week_1)

####FILMTITEL WEEK_1
films_1_titel=[i.text for i in soup.find_all(['h3','a'],{'class': 'filmlink'})]
df_1=pd.DataFrame(films_1_titel)
df_1.columns = ['Filmtitel']

# PAGELINKS WEEK 1
films_pglnk_1=[f'https://www.kino-zeit.de{i["href"]}' for i in soup.find_all(["h3","a"],{"class": "filmlink"})]
films_pglnk_1
df_1['page_link']=films_pglnk_1

#STARTTERMINE WEEK 1
films_start_1=[i.text for i in soup.find_all('div',{'class':'col-md-2 infospalte-1'})]
films_start_1 = re.findall(r'\d\d.\d\d.\d\d\d\d', str(films_start_1))
df_1['Starttermin']=films_start_1

#WEEK 1CHECKING REGIE, DARSTELLER, IMG, VERLEIH, PRODUNKTIONSLAND
regie_list=[]
darsteller_list=[]
list_img_url=[]
list_verleih=[]
list_prodland=[]

for i in df_1['page_link']:
    sub_page=make_soup(i)
    regie=[i.text.replace('\nRegie','').replace('\n\n','').split(',') for i in sub_page.find_all('div',{'class':'field field--name-field-regie field--type-entity-reference field--label-above'})]
    regie_list.append(regie[0])
    darsteller=[i.text.replace('\nDarsteller','').split('\n') for i in sub_page.find_all('div',{'class':'field field--name-field-hauptdarsteller field--type-entity-reference field--label-above'})]
    darsteller_list.append(darsteller)
    img_url=[i['data-big'] for i in sub_page.find_all('img',{'id':'headerbildbig'})]
    list_img_url.append(img_url)
    verleih=[i.text.replace('\nFilmverleih','').replace('\n\n','') for i in sub_page.find_all(['div','a'],{'class':'field field--name-field-distribution-film field--type-entity-reference field--label-above'})]
    list_verleih.append(verleih)
    prodland=[i.text.replace('\nProduktionsland','').replace('\n\n','') for i in sub_page.find_all(['div','a'],{'class':'field field--name-field-produktionsland field--type-entity-reference field--label-above'})]
    list_prodland.append(prodland)
    
df_1['Regie']=regie_list
df_1['Darsteller']=darsteller_list
df_1['Foto']=list_img_url
df_1['Verleih']=list_verleih
df_1['Produktionsland']=list_prodland
#df_1

# %%
####WEEK 2 ####
##URL###
week_2=''.join([f'https://www.kino-zeit.de/filme/filmstarts/{i["href"]}' for i in soup.find_all("a",{"class": "next btn btn-primary"})])
soup= make_soup(week_2)

####FILMTITEL WEEK_2
films_2_titel=[i.text for i in soup.find_all(['h3','a'],{'class': 'filmlink'})]
df_2=pd.DataFrame(films_2_titel)
df_2.columns = ['Filmtitel']

# PAGELINKS WEEK 2
films_pglnk_2=[f'https://www.kino-zeit.de{i["href"]}' for i in soup.find_all(["h3","a"],{"class": "filmlink"})]
films_pglnk_2
df_2['page_link']=films_pglnk_2
df_2

#STARTTERMINE WEEK 2
films_start_2=[i.text for i in soup.find_all('div',{'class':'col-md-2 infospalte-1'})]
films_start_2 = re.findall(r'\d\d.\d\d.\d\d\d\d', str(films_start_2))
df_2['Starttermin']=films_start_2



#WEEK 2 CHECKING REGIE, DARSTELLER, IMG, VERLEIH, PRODUNKTIONSLAND
regie_list=[]
darsteller_list=[]
list_img_url=[]
list_verleih=[]
list_prodland=[]

for i in df_2['page_link']:
    sub_page=make_soup(i)
    regie=[i.text.replace('\nRegie','').replace('\n\n','').split(',') for i in sub_page.find_all('div',{'class':'field field--name-field-regie field--type-entity-reference field--label-above'})]
    regie_list.append(regie[0])
    darsteller=[i.text.replace('\nDarsteller','').split('\n') for i in sub_page.find_all('div',{'class':'field field--name-field-hauptdarsteller field--type-entity-reference field--label-above'})]
    darsteller_list.append(darsteller)
    img_url=[i['data-big'] for i in sub_page.find_all('img',{'id':'headerbildbig'})]
    list_img_url.append(img_url)
    verleih=[i.text.replace('\nFilmverleih','').replace('\n\n','') for i in sub_page.find_all(['div','a'],{'class':'field field--name-field-distribution-film field--type-entity-reference field--label-above'})]
    list_verleih.append(verleih)
    prodland=[i.text.replace('\nProduktionsland','').replace('\n\n','') for i in sub_page.find_all(['div','a'],{'class':'field field--name-field-produktionsland field--type-entity-reference field--label-above'})]
    list_prodland.append(prodland)
    
df_2['Regie']=regie_list
df_2['Darsteller']=darsteller_list
df_2['Foto']=list_img_url
df_2['Verleih']=list_verleih
df_2['Produktionsland']=list_prodland
#df_2

# %%
####WEEK 3 ####
##URL###
week_3=''.join([f'https://www.kino-zeit.de/filme/filmstarts/{i["href"]}' for i in soup.find_all("a",{"class": "next btn btn-primary"})])
soup= make_soup(week_3)

####FILMTITEL WEEK_3
films_3_titel=[i.text for i in soup.find_all(['h3','a'],{'class': 'filmlink'})]
df_3=pd.DataFrame(films_3_titel)
df_3.columns = ['Filmtitel']

# PAGELINKS WEEK 3
films_pglnk_3=[f'https://www.kino-zeit.de{i["href"]}' for i in soup.find_all(["h3","a"],{"class": "filmlink"})]
films_pglnk_3
df_3['page_link']=films_pglnk_3
df_3

#STARTTERMINE WEEK 3
films_start_3=[i.text for i in soup.find_all('div',{'class':'col-md-2 infospalte-1'})]
films_start_3 = re.findall(r'\d\d.\d\d.\d\d\d\d', str(films_start_3))
df_3['Starttermin']=films_start_3
df_3

#WEEK 3 CHECKING REGIE, DARSTELLER, IMG, VERLEIH, PRODUNKTIONSLAND
regie_list=[]
darsteller_list=[]
list_img_url=[]
list_verleih=[]
list_prodland=[]

for i in df_3['page_link']:
    sub_page=make_soup(i)
    regie=[i.text.replace('\nRegie','').replace('\n\n','').split(',') for i in sub_page.find_all('div',{'class':'field field--name-field-regie field--type-entity-reference field--label-above'})]
    regie_list.append(regie[0])
    darsteller=[i.text.replace('\nDarsteller','').split('\n') for i in sub_page.find_all('div',{'class':'field field--name-field-hauptdarsteller field--type-entity-reference field--label-above'})]
    darsteller_list.append(darsteller)
    img_url=[i['data-big'] for i in sub_page.find_all('img',{'id':'headerbildbig'})]
    list_img_url.append(img_url)
    verleih=[i.text.replace('\nFilmverleih','').replace('\n\n','') for i in sub_page.find_all(['div','a'],{'class':'field field--name-field-distribution-film field--type-entity-reference field--label-above'})]
    list_verleih.append(verleih)
    prodland=[i.text.replace('\nProduktionsland','').replace('\n\n','') for i in sub_page.find_all(['div','a'],{'class':'field field--name-field-produktionsland field--type-entity-reference field--label-above'})]
    list_prodland.append(prodland)
    
df_3['Regie']=regie_list
df_3['Darsteller']=darsteller_list
df_3['Foto']=list_img_url
df_3['Verleih']=list_verleih
df_3['Produktionsland']=list_prodland
#df_3

# %%
####WEEK 4 #####
##URL###
week_4=''.join([f'https://www.kino-zeit.de/filme/filmstarts/{i["href"]}' for i in soup.find_all("a",{"class": "next btn btn-primary"})])
soup= make_soup(week_4)

####FILMTITEL WEEK_4
films_4_titel=[i.text for i in soup.find_all(['h3','a'],{'class': 'filmlink'})]
df_4=pd.DataFrame(films_4_titel)
df_4.columns = ['Filmtitel']

# PAGELINKS WEEK 4
films_pglnk_4=[f'https://www.kino-zeit.de{i["href"]}' for i in soup.find_all(["h3","a"],{"class": "filmlink"})]
films_pglnk_4
df_4['page_link']=films_pglnk_4
df_4

#STARTTERMINE WEEK 4
films_start_4=[i.text for i in soup.find_all('div',{'class':'col-md-2 infospalte-1'})]
films_start_4 = re.findall(r'\d\d.\d\d.\d\d\d\d', str(films_start_4))
df_4['Starttermin']=films_start_4
df_4

#WEEK 4 CHECKING REGIE, DARSTELLER, IMG, VERLEIH, PRODUNKTIONSLAND
regie_list=[]
darsteller_list=[]
list_img_url=[]
list_verleih=[]
list_prodland=[]

for i in df_4['page_link']:
    sub_page=make_soup(i)
    regie=[i.text.replace('\nRegie','').replace('\n\n','').split(',') for i in sub_page.find_all('div',{'class':'field field--name-field-regie field--type-entity-reference field--label-above'})]
    regie_list.append(regie[0])
    darsteller=[i.text.replace('\nDarsteller','').split('\n') for i in sub_page.find_all('div',{'class':'field field--name-field-hauptdarsteller field--type-entity-reference field--label-above'})]
    darsteller_list.append(darsteller)
    img_url=[i['data-big'] for i in sub_page.find_all('img',{'id':'headerbildbig'})]
    list_img_url.append(img_url)
    verleih=[i.text.replace('\nFilmverleih','').replace('\n\n','') for i in sub_page.find_all(['div','a'],{'class':'field field--name-field-distribution-film field--type-entity-reference field--label-above'})]
    list_verleih.append(verleih)
    prodland=[i.text.replace('\nProduktionsland','').replace('\n\n','') for i in sub_page.find_all(['div','a'],{'class':'field field--name-field-produktionsland field--type-entity-reference field--label-above'})]
    list_prodland.append(prodland)
    
df_4['Regie']=regie_list
df_4['Darsteller']=darsteller_list
df_4['Foto']=list_img_url
df_4['Verleih']=list_verleih
df_4['Produktionsland']=list_prodland
#df_4

# %%
df_starts=pd.concat([df_0, df_1, df_2, df_3, df_4], ignore_index=True)

# %%
#CLEAN ACTORS COLUMN
for i in range(len(df_starts.Darsteller)):
    if len(df_starts['Darsteller'].loc[i])==2:
        df_starts['Darsteller'].loc[i]=df_starts['Darsteller'].loc[i][0]
        df_starts['Darsteller'].loc[i]=list(filter(lambda x: x, list(df_starts['Darsteller'].loc[i])))

# %%
#TURN LISTS INTO STRINGS
for i in range(len(df_starts)):
    df_starts['Filmtitel']=df_starts['Filmtitel'].str.replace('\(\d\d\d\d\)','')
    df_starts['Produktionsland'][i]=''.join(df_starts['Produktionsland'][i]).replace('\n',', ')
    df_starts['Regie'][i]=', '.join(df_starts['Regie'][i]).replace('\n',', ')
    df_starts['Darsteller'][i]=', '.join(df_starts['Darsteller'][i])
    df_starts['Foto'][i]=''.join(df_starts['Foto'][i])
    df_starts['Verleih'][i]=''.join(df_starts['Verleih'][i]).replace('\n',', ')

# %%
###YOUTUBE TRAILER
#FUNCTION YOUTUBE LINK
from youtube_search import YoutubeSearch

def youtube_link (filmtitel, verleih):
    results = YoutubeSearch(f'{filmtitel} {verleih} Trailer', max_results=1).to_dict() #returns a dictionar
    if results ==[]:
        return('couldnt find youtube trailer')
    else:
        suffix = results[0]['url_suffix']
        youtube_link= f'www.youtube.com{suffix}'
        return(youtube_link)

#youtube_link(df_starts['Filmtitel'][1],df_starts['Verleih'][1])
df_starts['Trailer']='-'
for i in range(len(df_starts)):
    df_starts['Trailer'].loc[i] = youtube_link(df_starts['Filmtitel'][i],df_starts['Verleih'][i])

# %%
# Out:
#                                             Filmtitel  \
# 0   Contemporary Past - Die Gegenwart der Vergange...
# 1         Die Misswahl - Der Beginn einer Revolution
# 2                                      Drachenreiter
# 3                                    Enfant Terrible
# 4                                        Good Kisser
# ..                                                ...
# 59                                           Srbenka
# 60              The Booksellers - Aus Liebe zum Buch
# 61                         Und morgen die ganze Welt
# 62            Wildherz - Auf der Reise zu mir selbst
# 63                             Yakari - Der Kinofilm
#
#                               page_link Starttermin  \
# 0   https://www.kino-zeit.de/node/50404  01.10.2020
# 1   https://www.kino-zeit.de/node/48346  01.10.2020
# 2   https://www.kino-zeit.de/node/49005  01.10.2020
# 3   https://www.kino-zeit.de/node/48025  01.10.2020
# 4   https://www.kino-zeit.de/node/50833  01.10.2020
# ..                                  ...         ...
# 59  https://www.kino-zeit.de/node/43411  29.10.2020
# 60  https://www.kino-zeit.de/node/47837  29.10.2020
# 61  https://www.kino-zeit.de/node/50396  29.10.2020
# 62  https://www.kino-zeit.de/node/50377  29.10.2020
# 63  https://www.kino-zeit.de/node/48753  29.10.2020
#
#                              Regie  \
# 0                  Kamil Majchrzak
# 1               Philippa Lowthorpe
# 2                      Tomer Eshed
# 3                    Oskar Roehler
# 4                 Wendy Jo Carlton
# ..                             ...
# 59             Nebojša Slijepčević
# 60                      D.W. Young
# 61                 Julia von Heinz
# 62                      Caro Lobig
# 63  Toby Genkel, Xavier Giacometti
#
#                                            Darsteller  \
# 0
# 1   Keira Knightley, Gugu Mbatha-Raw, Jessie Buckl...
# 2
# 3   Oliver Masucci, Katja Riemann, Hary Prinz, Ant...
# 4   Kari Alison Hodge, Julia Eringer, Courtney McC...
# ..                                                ...
# 59
# 60
# 61  Mala Emde, Tonio Schneider, Luisa-Céline Gaffr...
# 62
# 63
#
#                                                  Foto  \
# 0   https://www.kino-zeit.de/sites/default/files/s...
# 1   https://www.kino-zeit.de/sites/default/files/s...
# 2   https://www.kino-zeit.de/sites/default/files/s...
# 3   https://www.kino-zeit.de/sites/default/files/s...
# 4   https://www.kino-zeit.de/sites/default/files/s...
# ..                                                ...
# 59  https://www.kino-zeit.de/sites/default/files/s...
# 60  https://www.kino-zeit.de/sites/default/files/s...
# 61  https://www.kino-zeit.de/sites/default/files/s...
# 62  https://www.kino-zeit.de/sites/default/files/s...
# 63  https://www.kino-zeit.de/sites/default/files/s...
#
#                                    Verleih                   Produktionsland  \
# 0            Les Funambules Filmproduktion                             Polen
# 1   eOne , Paramount Pictures Germany GmbH                    Großbritannien
# 2                   Constantin Filmverleih                       Deutschland
# 3                     Weltkino Filmverleih
# 4                Pro-Fun Media Filmverleih                               USA
# ..                                     ...                               ...
# 59                   Rise and Shine Cinema                          Kroatien
# 60                       Mindjazz Pictures                               USA
# 61                     Alamode Filmverleih                       Deutschland
# 62       catamaranfilms, barnsteiner-film                        Deutschland
# 63                                 Leonine  Belgien, Frankreich, Deutschland
#
#                                 Trailer
# 0   www.youtube.com/watch?v=giztjqXoQek
# 1   www.youtube.com/watch?v=3Qqy6IeVum8
# 2   www.youtube.com/watch?v=1BT7g6wcGhs
# 3   www.youtube.com/watch?v=taggXKKa0RA
# 4   www.youtube.com/watch?v=paHdPYlf21A
# ..                                  ...
# 59  www.youtube.com/watch?v=UkRO4bB_y-A
# 60         couldnt find youtube trailer
# 61  www.youtube.com/watch?v=nr6ieHK_sxw
# 62  www.youtube.com/watch?v=QN4dXdpIogQ
# 63  www.youtube.com/watch?v=jTQRG6Ep2S8
#
# [64 rows x 9 columns]

# %%
#SCRIPT IS DONE SOUND 
audio_file = "service-bell.mp3"
return_code = subprocess.call(["afplay", audio_file])

# %%
df_starts[df_starts['Produktionsland'].str.contains('Deutschland')]
# Out:
#                                             Filmtitel  \
# 2                                      Drachenreiter
# 5                    Gott, du kannst ein Arsch sein!
# 6                           Hurtigruten und Norwegen
# 7                         Jim Knopf und die wilde 13
# 13                           Es ist zu deinem Besten
# 17                                    Im Berg dahuim
# 18                                   Im Stillen laut
# 21                           Unser Boden, unser Erbe
# 30                 Martin Margiela - Mythos der Mode
# 33                                         Oeconomia
# 34  Rojo - Wenn alle schweigen, ist keiner unschul...
# 35                                     Sag du es mir
# 37                               Von Liebe und Krieg
# 39                                            Cortex
# 45         Regeln am Band, bei hoher Geschwindigkeit
# 49                                       Winterreise
# 54              Der Boandlkramer und die ewige Liebe
# 55                                   Glitzer & Staub
# 57                                            Schlaf
# 61                         Und morgen die ganze Welt
# 62            Wildherz - Auf der Reise zu mir selbst
# 63                             Yakari - Der Kinofilm
#
#                               page_link Starttermin  \
# 2   https://www.kino-zeit.de/node/49005  01.10.2020
# 5   https://www.kino-zeit.de/node/50476  01.10.2020
# 6   https://www.kino-zeit.de/node/50852  01.10.2020
# 7   https://www.kino-zeit.de/node/48472  01.10.2020
# 13  https://www.kino-zeit.de/node/50429  08.10.2020
# 17  https://www.kino-zeit.de/node/50889  08.10.2020
# 18  https://www.kino-zeit.de/node/50659  08.10.2020
# 21  https://www.kino-zeit.de/node/48460  08.10.2020
# 30  https://www.kino-zeit.de/node/48816  15.10.2020
# 33  https://www.kino-zeit.de/node/48739  15.10.2020
# 34  https://www.kino-zeit.de/node/43353  15.10.2020
# 35  https://www.kino-zeit.de/node/48412  15.10.2020
# 37  https://www.kino-zeit.de/node/50268  15.10.2020
# 39  https://www.kino-zeit.de/node/50644  22.10.2020
# 45  https://www.kino-zeit.de/node/48463  22.10.2020
# 49  https://www.kino-zeit.de/node/49515  22.10.2020
# 54  https://www.kino-zeit.de/node/48036  29.10.2020
# 55  https://www.kino-zeit.de/node/48512  29.10.2020
# 57  https://www.kino-zeit.de/node/48752  29.10.2020
# 61  https://www.kino-zeit.de/node/50396  29.10.2020
# 62  https://www.kino-zeit.de/node/50377  29.10.2020
# 63  https://www.kino-zeit.de/node/48753  29.10.2020
#
#                                   Regie  \
# 2                           Tomer Eshed
# 5                           André Erkau
# 6                    Volker Wischnowski
# 7                         Dennis Gansel
# 13                       Marc Rothemund
# 17  Thomas Rickenmann, Rahel von Gunten
# 18                        Therese Koppe
# 21                           Marc Uhlig
# 30                      Reiner Holzemer
# 33                       Carmen Losmann
# 34                    Benjámin Naishtat
# 35             Michael Fetter Nathansky
# 37                      Kasper Torsting
# 39                     Moritz Bleibtreu
# 45                       Yulia Lokshina
# 49     Anders Østergaard, Erzsébet Rácz
# 54                     Joseph Vilsmaier
# 55               Anna Koch, Julia Lemke
# 57                        Michael Venus
# 61                      Julia von Heinz
# 62                           Caro Lobig
# 63       Toby Genkel, Xavier Giacometti
#
#                                            Darsteller  \
# 2
# 5   Til Schweiger, Heike Makatsch, Benno Fürmann, ...
# 6
# 7   Henning Baum, Michael Bully Herbig, Solomon Go...
# 13  Heiner Lauterbach, Jürgen Vogel, Hilmi Sözer, ...
# 17
# 18
# 21
# 30
# 33
# 34  Darío Grandinetti, Andrea Frigerio, Alfredo Ca...
# 35  Christina Große, Marc Ben Puch, Gisa Flake, He...
# 37  Tom Wlaschiha, Ulrich Thomsen, Thure Lindhardt...
# 39  Moritz Bleibtreu, Jannis Niewöhner, Wotan Wilk...
# 45
# 49                                         Bruno Ganz
# 54  Michael Bully Herbig, Hape Kerkeling, Hannah H...
# 55
# 57  Sandra Hüller, Gro Swantje Kohlhof, Marion Kracht
# 61  Mala Emde, Tonio Schneider, Luisa-Céline Gaffr...
# 62
# 63
#
#                                                  Foto  \
# 2   https://www.kino-zeit.de/sites/default/files/s...
# 5   https://www.kino-zeit.de/sites/default/files/s...
# 6   https://www.kino-zeit.de/sites/default/files/s...
# 7   https://www.kino-zeit.de/sites/default/files/s...
# 13  https://www.kino-zeit.de/sites/default/files/s...
# 17  https://www.kino-zeit.de/sites/default/files/s...
# 18  https://www.kino-zeit.de/sites/default/files/s...
# 21  https://www.kino-zeit.de/sites/default/files/s...
# 30  https://www.kino-zeit.de/sites/default/files/s...
# 33  https://www.kino-zeit.de/sites/default/files/s...
# 34  https://www.kino-zeit.de/sites/default/files/s...
# 35  https://www.kino-zeit.de/sites/default/files/s...
# 37  https://www.kino-zeit.de/sites/default/files/s...
# 39  https://www.kino-zeit.de/sites/default/files/s...
# 45  https://www.kino-zeit.de/sites/default/files/s...
# 49  https://www.kino-zeit.de/sites/default/files/s...
# 54  https://www.kino-zeit.de/sites/default/files/s...
# 55  https://www.kino-zeit.de/sites/default/files/s...
# 57  https://www.kino-zeit.de/sites/default/files/s...
# 61  https://www.kino-zeit.de/sites/default/files/s...
# 62  https://www.kino-zeit.de/sites/default/files/s...
# 63  https://www.kino-zeit.de/sites/default/files/s...
#
#                                Verleih  \
# 2               Constantin Filmverleih
# 5                              Leonine
# 6             imFilm Agentur + Verleih
# 7     Warner Bros. Entertainment GmbH
# 13        STUDIOCANAL GmbH Filmverleih
# 17                      ExtraMileFilms
# 18         Salzgeber & Co. Medien GmbH
# 21                              W-Film
# 30             Filmwelt Verleihagentur
# 33      Neue Visionen Filmverleih GmbH
# 34             Cine Global Filmverleih
# 35                       missingFILMs
# 37                         Tamtam Film
# 39                        Warner Bros.
# 45                  jip Film & Verleih
# 49            Real Fiction Filmverleih
# 54                             Leonine
# 55  Port-Au-Prince Pictures, 24 Bilder
# 57                           Salzgeber
# 61                 Alamode Filmverleih
# 62   catamaranfilms, barnsteiner-film
# 63                             Leonine
#
#                                  Produktionsland  \
# 2                                    Deutschland
# 5                                    Deutschland
# 6                                    Deutschland
# 7                                    Deutschland
# 13                                   Deutschland
# 17                                   Deutschland
# 18                                   Deutschland
# 21                                   Deutschland
# 30                          Deutschland, Belgien
# 33                                   Deutschland
# 34                      Argentinien, Deutschland
# 35                                   Deutschland
# 37  Dänemark, Deutschland, Tschechische Republik
# 39                                   Deutschland
# 45                                   Deutschland
# 49                         Dänemark, Deutschland
# 54                                   Deutschland
# 55                                   Deutschland
# 57                                   Deutschland
# 61                                   Deutschland
# 62                                   Deutschland
# 63              Belgien, Frankreich, Deutschland
#
#                                 Trailer
# 2   www.youtube.com/watch?v=1BT7g6wcGhs
# 5   www.youtube.com/watch?v=WQHiwRNvSiE
# 6          couldnt find youtube trailer
# 7   www.youtube.com/watch?v=JwG3kZSox2g
# 13  www.youtube.com/watch?v=NGtsSuAGQro
# 17  www.youtube.com/watch?v=LfeuDr9weCA
# 18  www.youtube.com/watch?v=AZ45RU_RFWM
# 21  www.youtube.com/watch?v=0QQYS1wJl5g
# 30  www.youtube.com/watch?v=EvrQX4POKtg
# 33  www.youtube.com/watch?v=x5ZvsuSjlas
# 34  www.youtube.com/watch?v=4QhqxLA3aH4
# 35  www.youtube.com/watch?v=UerHnKI8xZs
# 37  www.youtube.com/watch?v=t406bUnfYGo
# 39  www.youtube.com/watch?v=1rPsZmICIn4
# 45  www.youtube.com/watch?v=nMr_Fwe2yus
# 49  www.youtube.com/watch?v=zTUppQnK_M0
# 54  www.youtube.com/watch?v=1FWIORy_auU
# 55         couldnt find youtube trailer
# 57  www.youtube.com/watch?v=maEJhZNXlH0
# 61  www.youtube.com/watch?v=nr6ieHK_sxw
# 62  www.youtube.com/watch?v=QN4dXdpIogQ
# 63  www.youtube.com/watch?v=jTQRG6Ep2S8

# %%
df_starts['Foto']
# Out:
# 0     https://www.kino-zeit.de/sites/default/files/s...
# 1     https://www.kino-zeit.de/sites/default/files/s...
# 2     https://www.kino-zeit.de/sites/default/files/s...
# 3     https://www.kino-zeit.de/sites/default/files/s...
# 4     https://www.kino-zeit.de/sites/default/files/s...
#                             ...
# 59    https://www.kino-zeit.de/sites/default/files/s...
# 60    https://www.kino-zeit.de/sites/default/files/s...
# 61    https://www.kino-zeit.de/sites/default/files/s...
# 62    https://www.kino-zeit.de/sites/default/files/s...
# 63    https://www.kino-zeit.de/sites/default/files/s...
# Name: Foto, Length: 64, dtype: object
